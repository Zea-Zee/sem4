# %%
# !pip install -U openmim
# !mim install mmengine
# !mim install mmcv
# !mim install mmdet
# !mim install mmpose
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /usr/lib/python3/dist-packages (from openmim) (8.0.3)
# Requirement already satisfied: colorama in /usr/lib/python3/dist-packages (from openmim) (0.4.4)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /home/zea/.local/lib/python3.10/site-packages (from openmim) (2.2.0)
# Requirement already satisfied: pip>=19.3 in /home/zea/.local/lib/python3.10/site-packages (from openmim) (24.0)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from openmim) (2.25.1)
# Collecting rich (from openmim)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting tabulate (from openmim)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from model-index->openmim) (5.4.1)
# Requirement already satisfied: markdown in /home/zea/.local/lib/python3.10/site-packages (from model-index->openmim) (3.5.2)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pycryptodome (from opendatalab->openmim)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: tqdm in /home/zea/.local/lib/python3.10/site-packages (from opendatalab->openmim) (4.66.2)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.0.34-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/zea/.local/lib/python3.10/site-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zea/.local/lib/python3.10/site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->openmim) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/zea/.local/lib/python3.10/site-packages (from pandas->openmim) (2023.4)
# Collecting markdown-it-py>=2.2.0 (from rich->openmim)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich->openmim)
#   Downloading pygments-2.17.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->openmim)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 808.1 kB/s eta 0:00:00 kB/s eta 0:00:01:01
#   Preparing metadata (setup.py) ... done
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting pyyaml (from model-index->openmim)
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 961.6 kB/s eta 0:00:0031m1.5 MB/s eta 0:00:01
# Collecting charset-normalizer<4,>=2 (from requests->openmim)
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/zea/.local/lib/python3.10/site-packages (from requests->openmim) (2.10)
# Collecting urllib3<1.27,>=1.21.1 (from requests->openmim)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 913.9 kB/s eta 0:00:00MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /home/zea/.local/lib/python3.10/site-packages (from requests->openmim) (2023.7.22)
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 847.4 kB/s eta 0:00:00MB/s eta 0:00:01:01
#   Preparing metadata (setup.py) ... done
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.14.0.tar.gz (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.0/443.0 kB 935.5 kB/s eta 0:00:00 kB/s eta 0:00:01:01
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cryptography>=2.6.0 in /usr/lib/python3/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (3.4.8)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 870.9 kB/s eta 0:00:00B/s eta 0:00:01
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 725.8 kB/s eta 0:00:00 kB/s eta 0:00:01
# Downloading pygments-2.17.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 939.8 kB/s eta 0:00:000:00:010:00:01:01
# Downloading openxlab-0.0.34-py3-none-any.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 1.0 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 567.8 kB/s eta 0:00:001m? eta -:--:--
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 1.0 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 1.1 MB/s eta 0:00:001.2 MB/s eta 0:00:01
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 1.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 1.1 MB/s eta 0:00:001.1 MB/s eta 0:00:01
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 1.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 1.1 MB/s eta 0:00:00 MB/s eta 0:00:0101
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 860.6 kB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 857.0 kB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading aliyun_python_sdk_kms-2.16.2-py2.py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 816.8 kB/s eta 0:00:000:00:016m0:00:01
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112375 sha256=e2920ef4b84076c1383d03b5720c56d6d34d8b68631d9f5e796eb2343b9d92a0
#   Stored in directory: /home/zea/.cache/pip/wheels/87/04/7b/7e61b8157fdf211c5131375240d0d86ca82e2a88ead9672c88
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.14.0-py3-none-any.whl size=535295 sha256=2a05474ae40883f3bd664d44a343e71cca0274258015f4c35162ec1bcfbc501f
#   Stored in directory: /home/zea/.cache/pip/wheels/16/3c/68/b7eab618d9f1d5e7d386296f1e07e2cf36aaa1eb5161885038
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31404 sha256=a1d0b42fdd81343bd5ffae25450d2d019cc0e4f755355fbf027f34da392ed731
#   Stored in directory: /home/zea/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: pytz, crcmod, urllib3, tqdm, tabulate, setuptools, pyyaml, pygments, pycryptodome, ordered-set, mdurl, jmespath, charset-normalizer, requests, model-index, markdown-it-py, aliyun-python-sdk-core, rich, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.2
#     Uninstalling tqdm-4.66.2:
#       Successfully uninstalled tqdm-4.66.2
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.1.0
#     Uninstalling setuptools-69.1.0:
#       Successfully uninstalled setuptools-69.1.0
#   Attempting uninstall: jmespath
#     Found existing installation: jmespath 1.0.1
#     Uninstalling jmespath-1.0.1:
#       Successfully uninstalled jmespath-1.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yolov5 7.0.13 requires setuptools>=65.5.1, but you have setuptools 60.2.0 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.14.0 aliyun-python-sdk-kms-2.16.2 charset-normalizer-3.3.2 crcmod-1.7 jmespath-0.10.0 markdown-it-py-3.0.0 mdurl-0.1.2 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.0.34 ordered-set-4.1.0 oss2-2.17.0 pycryptodome-3.20.0 pygments-2.17.2 pytz-2023.4 pyyaml-6.0.1 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tabulate-0.9.0 tqdm-4.65.2 urllib3-1.26.18
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.2.0/index.html
# Collecting mmengine
#   Downloading mmengine-0.10.3-py3-none-any.whl.metadata (20 kB)
# Collecting addict (from mmengine)
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: matplotlib in /home/zea/.local/lib/python3.10/site-packages (from mmengine) (3.8.2)
# Requirement already satisfied: numpy in /home/zea/.local/lib/python3.10/site-packages (from mmengine) (1.26.4)
# Requirement already satisfied: pyyaml in /home/zea/.local/lib/python3.10/site-packages (from mmengine) (6.0.1)
# Requirement already satisfied: rich in /home/zea/.local/lib/python3.10/site-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in /home/zea/.local/lib/python3.10/site-packages (from mmengine) (2.4.0)
# Collecting yapf (from mmengine)
#   Downloading yapf-0.40.2-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /home/zea/.local/lib/python3.10/site-packages (from mmengine) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib->mmengine) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mmengine) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib->mmengine) (21.3)
# Requirement already satisfied: pillow>=8 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mmengine) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zea/.local/lib/python3.10/site-packages (from rich->mmengine) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zea/.local/lib/python3.10/site-packages (from rich->mmengine) (2.17.2)
# Collecting importlib-metadata>=6.6.0 (from yapf->mmengine)
#   Downloading importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/zea/.local/lib/python3.10/site-packages (from yapf->mmengine) (4.2.0)
# Collecting tomli>=2.0.1 (from yapf->mmengine)
#   Downloading tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib->mmengine) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=6.6.0->yapf->mmengine) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/zea/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Downloading mmengine-0.10.3-py3-none-any.whl (451 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 1.2 MB/s eta 0:00:001.3 MB/s eta 0:00:01
# Downloading yapf-0.40.2-py3-none-any.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 389.6 kB/s eta 0:00:001m385.9 kB/s eta 0:00:01
# Downloading importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Installing collected packages: addict, tomli, importlib-metadata, yapf, mmengine
# Successfully installed addict-2.4.0 importlib-metadata-7.0.1 mmengine-0.10.3 tomli-2.0.1 yapf-0.40.2
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.2.0/index.html
# Collecting mmcv
#   Downloading mmcv-2.1.0.tar.gz (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.4/471.4 kB 545.3 kB/s eta 0:00:00 kB/s eta 0:00:01:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: addict in /home/zea/.local/lib/python3.10/site-packages (from mmcv) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /home/zea/.local/lib/python3.10/site-packages (from mmcv) (0.10.3)
# Requirement already satisfied: numpy in /home/zea/.local/lib/python3.10/site-packages (from mmcv) (1.26.4)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from mmcv) (21.3)
# Requirement already satisfied: Pillow in /home/zea/.local/lib/python3.10/site-packages (from mmcv) (10.2.0)
# Requirement already satisfied: pyyaml in /home/zea/.local/lib/python3.10/site-packages (from mmcv) (6.0.1)
# Requirement already satisfied: yapf in /home/zea/.local/lib/python3.10/site-packages (from mmcv) (0.40.2)
# Requirement already satisfied: matplotlib in /home/zea/.local/lib/python3.10/site-packages (from mmengine>=0.3.0->mmcv) (3.8.2)
# Requirement already satisfied: rich in /home/zea/.local/lib/python3.10/site-packages (from mmengine>=0.3.0->mmcv) (13.4.2)
# Requirement already satisfied: termcolor in /home/zea/.local/lib/python3.10/site-packages (from mmengine>=0.3.0->mmcv) (2.4.0)
# Requirement already satisfied: opencv-python>=3 in /home/zea/.local/lib/python3.10/site-packages (from mmengine>=0.3.0->mmcv) (4.7.0.72)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /home/zea/.local/lib/python3.10/site-packages (from yapf->mmcv) (7.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/zea/.local/lib/python3.10/site-packages (from yapf->mmcv) (4.2.0)
# Requirement already satisfied: tomli>=2.0.1 in /home/zea/.local/lib/python3.10/site-packages (from yapf->mmcv) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zea/.local/lib/python3.10/site-packages (from rich->mmengine>=0.3.0->mmcv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zea/.local/lib/python3.10/site-packages (from rich->mmengine>=0.3.0->mmcv) (2.17.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib->mmengine>=0.3.0->mmcv) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /home/zea/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv) (0.1.2)
# Building wheels for collected packages: mmcv
#   Building wheel for mmcv (setup.py) ... |^C
# anceled
# ERROR: Operation cancelled by user
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.2.0/index.html
# Collecting mmdet
#   Downloading mmdet-3.3.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: matplotlib in /home/zea/.local/lib/python3.10/site-packages (from mmdet) (3.8.2)
# Requirement already satisfied: numpy in /home/zea/.local/lib/python3.10/site-packages (from mmdet) (1.26.4)
# Collecting pycocotools (from mmdet)
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: scipy in /home/zea/.local/lib/python3.10/site-packages (from mmdet) (1.12.0)
# Requirement already satisfied: shapely in /home/zea/.local/lib/python3.10/site-packages (from mmdet) (2.0.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from mmdet) (1.16.0)
# Requirement already satisfied: terminaltables in /home/zea/.local/lib/python3.10/site-packages (from mmdet) (3.1.10)
# Requirement already satisfied: tqdm in /home/zea/.local/lib/python3.10/site-packages (from mmdet) (4.65.2)
# Collecting mmcv<2.2.0,>=2.0.0rc4 (from mmdet)
#   Using cached mmcv-2.1.0.tar.gz (471 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: mmengine<1.0.0,>=0.7.1 in /home/zea/.local/lib/python3.10/site-packages (from mmdet) (0.10.3)
# Requirement already satisfied: addict in /home/zea/.local/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmdet) (2.4.0)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from mmcv<2.2.0,>=2.0.0rc4->mmdet) (21.3)
# Requirement already satisfied: Pillow in /home/zea/.local/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmdet) (10.2.0)
# Requirement already satisfied: pyyaml in /home/zea/.local/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmdet) (6.0.1)
# Requirement already satisfied: yapf in /home/zea/.local/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmdet) (0.40.2)
# Requirement already satisfied: rich in /home/zea/.local/lib/python3.10/site-packages (from mmengine<1.0.0,>=0.7.1->mmdet) (13.4.2)
# Requirement already satisfied: termcolor in /home/zea/.local/lib/python3.10/site-packages (from mmengine<1.0.0,>=0.7.1->mmdet) (2.4.0)
# Requirement already satisfied: opencv-python>=3 in /home/zea/.local/lib/python3.10/site-packages (from mmengine<1.0.0,>=0.7.1->mmdet) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmdet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmdet) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib->mmdet) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mmdet) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mmdet) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmdet) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zea/.local/lib/python3.10/site-packages (from rich->mmengine<1.0.0,>=0.7.1->mmdet) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zea/.local/lib/python3.10/site-packages (from rich->mmengine<1.0.0,>=0.7.1->mmdet) (2.17.2)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /home/zea/.local/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0rc4->mmdet) (7.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/zea/.local/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0rc4->mmdet) (4.2.0)
# Requirement already satisfied: tomli>=2.0.1 in /home/zea/.local/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0rc4->mmdet) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv<2.2.0,>=2.0.0rc4->mmdet) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/zea/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine<1.0.0,>=0.7.1->mmdet) (0.1.2)
# Downloading mmdet-3.3.0-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 1.2 MB/s eta 0:00:00m eta 0:00:010:01:010m
# Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 1.2 MB/s eta 0:00:000:00:01m eta 0:00:01
# Building wheels for collected packages: mmcv
#   Building wheel for mmcv (setup.py) ... /^C
# anceled
# ERROR: Operation cancelled by user
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.2.0/index.html
# Collecting mmpose
#   Downloading mmpose-1.3.1-py2.py3-none-any.whl.metadata (29 kB)
# Collecting chumpy (from mmpose)
#   Downloading chumpy-0.70.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting json-tricks (from mmpose)
#   Downloading json_tricks-3.17.3-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: matplotlib in /home/zea/.local/lib/python3.10/site-packages (from mmpose) (3.8.2)
# Collecting munkres (from mmpose)
#   Downloading munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Requirement already satisfied: numpy in /home/zea/.local/lib/python3.10/site-packages (from mmpose) (1.26.4)
# Requirement already satisfied: opencv-python in /home/zea/.local/lib/python3.10/site-packages (from mmpose) (4.7.0.72)
# Requirement already satisfied: pillow in /home/zea/.local/lib/python3.10/site-packages (from mmpose) (10.2.0)
# Requirement already satisfied: scipy in /home/zea/.local/lib/python3.10/site-packages (from mmpose) (1.12.0)
# Requirement already satisfied: torchvision in /home/zea/.local/lib/python3.10/site-packages (from mmpose) (0.17.0)
# Collecting xtcocotools>=1.12 (from mmpose)
#   Downloading xtcocotools-1.14.3-cp310-cp310-manylinux1_x86_64.whl.metadata (364 bytes)
# Collecting mmcv<2.2.0,>=2.0.0 (from mmpose)
#   Using cached mmcv-2.1.0.tar.gz (471 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mmdet<3.3.0,>=3.0.0 (from mmpose)
#   Downloading mmdet-3.2.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: mmengine<1.0.0,>=0.4.0 in /home/zea/.local/lib/python3.10/site-packages (from mmpose) (0.10.3)
# Requirement already satisfied: addict in /home/zea/.local/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0->mmpose) (2.4.0)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from mmcv<2.2.0,>=2.0.0->mmpose) (21.3)
# Requirement already satisfied: pyyaml in /home/zea/.local/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0->mmpose) (6.0.1)
# Requirement already satisfied: yapf in /home/zea/.local/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0->mmpose) (0.40.2)
# Collecting pycocotools (from mmdet<3.3.0,>=3.0.0->mmpose)
#   Using cached pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: shapely in /home/zea/.local/lib/python3.10/site-packages (from mmdet<3.3.0,>=3.0.0->mmpose) (2.0.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from mmdet<3.3.0,>=3.0.0->mmpose) (1.16.0)
# Requirement already satisfied: terminaltables in /home/zea/.local/lib/python3.10/site-packages (from mmdet<3.3.0,>=3.0.0->mmpose) (3.1.10)
# Requirement already satisfied: tqdm in /home/zea/.local/lib/python3.10/site-packages (from mmdet<3.3.0,>=3.0.0->mmpose) (4.65.2)
# Requirement already satisfied: rich in /home/zea/.local/lib/python3.10/site-packages (from mmengine<1.0.0,>=0.4.0->mmpose) (13.4.2)
# Requirement already satisfied: termcolor in /home/zea/.local/lib/python3.10/site-packages (from mmengine<1.0.0,>=0.4.0->mmpose) (2.4.0)
# Requirement already satisfied: setuptools>=18.0 in /home/zea/.local/lib/python3.10/site-packages (from xtcocotools>=1.12->mmpose) (60.2.0)
# Collecting cython>=0.27.3 (from xtcocotools>=1.12->mmpose)
#   Downloading Cython-3.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmpose) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmpose) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib->mmpose) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mmpose) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mmpose) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmpose) (2.8.2)
# Requirement already satisfied: requests in /home/zea/.local/lib/python3.10/site-packages (from torchvision->mmpose) (2.28.2)
# Requirement already satisfied: torch==2.2.0 in /home/zea/.local/lib/python3.10/site-packages (from torchvision->mmpose) (2.2.0)
# Requirement already satisfied: filelock in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (4.9.0)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch==2.2.0->torchvision->mmpose) (1.9)
# Requirement already satisfied: networkx in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch==2.2.0->torchvision->mmpose) (3.0.3)
# Requirement already satisfied: fsspec in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/zea/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision->mmpose) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/zea/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.0->torchvision->mmpose) (12.3.101)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zea/.local/lib/python3.10/site-packages (from requests->torchvision->mmpose) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/zea/.local/lib/python3.10/site-packages (from requests->torchvision->mmpose) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/zea/.local/lib/python3.10/site-packages (from requests->torchvision->mmpose) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zea/.local/lib/python3.10/site-packages (from requests->torchvision->mmpose) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zea/.local/lib/python3.10/site-packages (from rich->mmengine<1.0.0,>=0.4.0->mmpose) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zea/.local/lib/python3.10/site-packages (from rich->mmengine<1.0.0,>=0.4.0->mmpose) (2.17.2)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /home/zea/.local/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0->mmpose) (7.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/zea/.local/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0->mmpose) (4.2.0)
# Requirement already satisfied: tomli>=2.0.1 in /home/zea/.local/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0->mmpose) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv<2.2.0,>=2.0.0->mmpose) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/zea/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine<1.0.0,>=0.4.0->mmpose) (0.1.2)
# Downloading mmpose-1.3.1-py2.py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading mmdet-3.2.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.3 MB/s eta 0:00:000:00:010:00:01:01
# Downloading xtcocotools-1.14.3-cp310-cp310-manylinux1_x86_64.whl (436 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.0/436.0 kB 1.0 MB/s eta 0:00:001.1 MB/s eta 0:00:01
# Downloading json_tricks-3.17.3-py2.py3-none-any.whl (27 kB)
# Downloading Cython-3.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 672.8 kB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
# Building wheels for collected packages: mmcv, chumpy
#   Building wheel for mmcv (setup.py) ... done
#   Created wheel for mmcv: filename=mmcv-2.1.0-cp310-cp310-linux_x86_64.whl size=28260708 sha256=f09a7b839157d3ea0a1ab79e796a04298922071619be67241d7e400c80154ed5
#   Stored in directory: /home/zea/.cache/pip/wheels/8b/09/35/94a7f7ba6a00e3810abd0492340e4cbba0ff3d443120a94120
#   Building wheel for chumpy (setup.py) ... done
#   Created wheel for chumpy: filename=chumpy-0.70-py3-none-any.whl size=58285 sha256=7dbe210d49c9fc14cf2fd0f89c52c91cf7446ae0bc383f1d170fbc7afcbb557a
#   Stored in directory: /home/zea/.cache/pip/wheels/e0/c1/ef/29ba7be03653a29ef6f2c3e1956d6c4d8877f2b243af411db1
# Successfully built mmcv chumpy
# Installing collected packages: munkres, json-tricks, cython, chumpy, xtcocotools, pycocotools, mmcv, mmdet, mmpose
# Successfully installed chumpy-0.70 cython-3.0.8 json-tricks-3.17.3 mmcv-2.1.0 mmdet-3.2.0 mmpose-1.3.1 munkres-1.1.4 pycocotools-2.0.7 xtcocotools-1.14.3

# %%
# !pip install mmaction2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mmaction2 in /home/zea/.local/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: decord>=0.4.1 in /home/zea/.local/lib/python3.10/site-packages (from mmaction2) (0.6.0)
# Requirement already satisfied: einops in /home/zea/.local/lib/python3.10/site-packages (from mmaction2) (0.7.0)
# Requirement already satisfied: matplotlib in /home/zea/.local/lib/python3.10/site-packages (from mmaction2) (3.8.2)
# Requirement already satisfied: numpy in /home/zea/.local/lib/python3.10/site-packages (from mmaction2) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /home/zea/.local/lib/python3.10/site-packages (from mmaction2) (4.9.0.80)
# Requirement already satisfied: Pillow in /home/zea/.local/lib/python3.10/site-packages (from mmaction2) (10.2.0)
# Requirement already satisfied: scipy in /home/zea/.local/lib/python3.10/site-packages (from mmaction2) (1.12.0)
# Requirement already satisfied: torch>=1.3 in /home/zea/.local/lib/python3.10/site-packages (from mmaction2) (2.2.0)
# Requirement already satisfied: filelock in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (4.9.0)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch>=1.3->mmaction2) (1.9)
# Requirement already satisfied: networkx in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=1.3->mmaction2) (3.0.3)
# Requirement already satisfied: fsspec in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/zea/.local/lib/python3.10/site-packages (from torch>=1.3->mmaction2) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/zea/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3->mmaction2) (12.3.101)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmaction2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmaction2) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib->mmaction2) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mmaction2) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib->mmaction2) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mmaction2) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zea/.local/lib/python3.10/site-packages (from matplotlib->mmaction2) (2.8.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib->mmaction2) (1.16.0)

# %%
# !mim download mmaction2 --config tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb --dest .

# %%
# The demo.mp4 and label_map_k400.txt are both from Kinetics-400
python demo/demo.py tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb.py \
    tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb_20220906-2692d16c.pth \
    demo/demo.mp4 tools/data/kinetics/label_map_k400.txt
# Out:
#   File "/tmp/ipykernel_7993/3494037412.py", line 2
#     python demo/demo.py tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb.py \
#                                                           ^
# SyntaxError: invalid decimal literal

# %%
from operator import itemgetter
from mmaction.apis import init_recognizer, inference_recognizer

config_file = 'tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb.py'
checkpoint_file = 'tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb_20220906-2692d16c.pth'
video_file = 'demo/demo.mp4'
label_file = 'tools/data/kinetics/label_map_k400.txt'
model = init_recognizer(config_file, checkpoint_file, device='cpu')  # or device='cuda:0'
pred_result = inference_recognizer(model, video_file)

pred_scores = pred_result.pred_score.tolist()
score_tuples = tuple(zip(range(len(pred_scores)), pred_scores))
score_sorted = sorted(score_tuples, key=itemgetter(1), reverse=True)
top5_label = score_sorted[:5]

labels = open(label_file).readlines()
labels = [x.strip() for x in labels]
results = [(labels[k[0]], k[1]) for k in top5_label]

print('The top-5 labels with corresponding scores are:')
for result in results:
    print(f'{result[0]}: ', result[1])
